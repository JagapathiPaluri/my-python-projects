# %%
print("Heelo world")
# Out:
# Heelo world

# %% [markdown]
# lets start a student details

# %%
name="subbarao"
age=21
GPA=3.67
play_kabbadi=True

print(name, age, GPA, play_kabbadi)
# Out:
# subbarao 21 3.67 True
